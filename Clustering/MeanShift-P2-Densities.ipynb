# %% [markdown]
# # Mean Shift with Different Density Cluster Sizes

# %%
# Mean Shift Custering
# import libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importing dataset

dataset = pd.read_csv('Artificial.csv')
data = dataset.iloc[:,[0,1]].values
data.shape
# Out:
# (1008, 2)

# %%
# visualizing dataset

plt.scatter(data[:,0], data[:,1],s = 10, c = 'black')

# %%
# Elbow method for determining the number of cluster
from sklearn.cluster import KMeans
wcss = []
for i in range (1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting Mean Shift algorithim to dataset

from sklearn.cluster import MeanShift, estimate_bandwidth

bandwidth = estimate_bandwidth(data, quantile= 0.25)

meanshift = MeanShift(bandwidth= bandwidth)
labels = meanshift.fit_predict(data)
np.unique(labels)
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
# Visualizing the clusters
plt.scatter(data[labels == 0,0], data[labels == 0,1], s = 10, c = 'blue')
plt.scatter(data[labels == 1,0], data[labels == 1,1], s = 10, c = 'red')
plt.scatter(data[labels == 2,0], data[labels == 2,1], s = 10, c = 'pink')
plt.scatter(data[labels == 3,0], data[labels == 3,1], s = 10, c = 'green')
plt.scatter(data[labels == 4,0], data[labels == 4,1], s = 10, c = 'brown')
plt.scatter(data[labels == 5,0], data[labels == 5,1], s = 10, c = 'magenta')
plt.scatter(data[labels == 6,0], data[labels == 6,1], s = 10, c = 'orange')
plt.scatter(data[labels == 7,0], data[labels == 7,1], s = 10, c = 'yellow')
plt.scatter(data[labels == 8,0], data[labels == 8,1], s = 10, c = 'silver')

plt.title('Clusters result on the dataset')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()
